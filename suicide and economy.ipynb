# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
gdp = pd.read_csv("/Users/jiahaoshen/Desktop/Stats170/gdp.csv",thousands=',')

# %%
gdp.head(5)
# Out:
#    Year      Gross domestic product  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  1929                      104556         NaN         NaN         NaN
# 1  1930                       92160         NaN         NaN         NaN
# 2  1931                       77391         NaN         NaN         NaN
# 3  1932                       59522         NaN         NaN         NaN
# 4  1933                       57154         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9     ...       \
# 0         NaN         NaN         NaN         NaN         NaN     ...
# 1         NaN         NaN         NaN         NaN         NaN     ...
# 2         NaN         NaN         NaN         NaN         NaN     ...
# 3         NaN         NaN         NaN         NaN         NaN     ...
# 4         NaN         NaN         NaN         NaN         NaN     ...
#
#    Unnamed: 81  Unnamed: 82  Unnamed: 83  Unnamed: 84  Unnamed: 85  \
# ...

# %%
gdp.columns
# Out:
# Index(['Year', '    Gross domestic product', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
gdp = gdp.rename(index=str, columns={'    Gross domestic product': 'gdp'})

# %%
gdp = gdp[['Year','gdp']]
gdp.head(5)
# Out:
#    Year     gdp
# 0  1929  104556
# 1  1930   92160
# 2  1931   77391
# 3  1932   59522
# 4  1933   57154

# %%
gdp5 = gdp[0:5]
gdp5
# Out:
#    Year     gdp
# 0  1929  104556
# 1  1930   92160
# 2  1931   77391
# 3  1932   59522
# 4  1933   57154

# %%
gdp.gdp.astype(int)
# Out:
# 0       104556
# 1        92160
# 2        77391
# 3        59522
# 4        57154
# 5        66800
# 6        74241
# 7        84830
# 8        93003
# 9        87352
# 10       93437
# 11      102899
# 12      129309
# 13      165952
# 14      203084
# 15      224447
# 16      228007
# 17      227535
# 18      249616
# 19      274468
# 20      272475
# 21      299827
# 22      346914
# 23      367341
# 24      389218
# 25      390549
# 26      425478
# 27      449353
# 28      474039
# 29      481229
#         ...
# 60     5641580
# 61     5963144
# 62     6158129
# 63     6520327
# 64     6858559
# 65     7287236
# 66     7639749
# 67     8073122
# 68     8577552
# 69     9062817
# 70     9630663
# 71    10252347
# 72    10581822
# 73    10936418
# 74    11458246
# 75    12213730
# 76    13036637
# 77    13814609
# 78    14451860
# 79    14712845
# 80    14448932
# 81    14992052
# 82    15542582
# 83    16197007
# 84    16784851
# 85    17521747
# 86    18219297
# 87    18707189
# ...

# %%
gdp.Year.astype(int)
# Out:
# 0     1929
# 1     1930
# 2     1931
# 3     1932
# 4     1933
# 5     1934
# 6     1935
# 7     1936
# 8     1937
# 9     1938
# 10    1939
# 11    1940
# 12    1941
# 13    1942
# 14    1943
# 15    1944
# 16    1945
# 17    1946
# 18    1947
# 19    1948
# 20    1949
# 21    1950
# 22    1951
# 23    1952
# 24    1953
# 25    1954
# 26    1955
# 27    1956
# 28    1957
# 29    1958
#       ...
# 60    1989
# 61    1990
# 62    1991
# 63    1992
# 64    1993
# 65    1994
# 66    1995
# 67    1996
# 68    1997
# 69    1998
# 70    1999
# 71    2000
# 72    2001
# 73    2002
# 74    2003
# 75    2004
# 76    2005
# 77    2006
# 78    2007
# 79    2008
# 80    2009
# 81    2010
# 82    2011
# 83    2012
# 84    2013
# 85    2014
# 86    2015
# 87    2016
# 88    2017
# 89    2018
# Name: Year, Length: 90, dtype: int64

# %%
gdp = gdp[70:88]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_xticks(gdp.Year)
plt.plot(gdp.Year,gdp.gdp)
ax.set_title('GDP')
# Out:
# Text(0.5,1,'GDP')

# %%
stategdp = pd.read_csv("/Users/jiahaoshen/Desktop/Stats170/data/SAGDP2N__ALL_AREAS_1997_2017.csv")
stategdp.head(20)
# Out:
#       GeoFIPS         GeoName Region TableName  \
# 0    "00000"   United States*          SAGDP2N
# 1    "00000"   United States*          SAGDP2N
# 2    "00000"   United States*          SAGDP2N
# 3    "00000"   United States*          SAGDP2N
# 4    "00000"   United States*          SAGDP2N
# 5    "00000"   United States*          SAGDP2N
# 6    "00000"   United States*          SAGDP2N
# 7    "00000"   United States*          SAGDP2N
# 8    "00000"   United States*          SAGDP2N
# 9    "00000"   United States*          SAGDP2N
# 10   "00000"   United States*          SAGDP2N
# 11   "00000"   United States*          SAGDP2N
# 12   "00000"   United States*          SAGDP2N
# 13   "00000"   United States*          SAGDP2N
# 14   "00000"   United States*          SAGDP2N
# 15   "00000"   United States*          SAGDP2N
# 16   "00000"   United States*          SAGDP2N
# 17   "00000"   United States*          SAGDP2N
# 18   "00000"   United States*          SAGDP2N
# ...

# %%
stategdp.columns
# Out:
# Index(['GeoFIPS', 'GeoName', 'Region', 'TableName', 'ComponentName', 'Unit',
#        'IndustryId', 'IndustryClassification', 'Description', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017'],
#       dtype='object')

# %%
stategdp = stategdp.drop(columns=['GeoFIPS','Region','TableName','ComponentName','Unit','IndustryId','IndustryClassification'])

# %%
stategdp.head(20)
# Out:
#           State       1997       1998      1999      2000       2001  \
# 0       Alabama   104087.4   109404.3  115030.9  119242.4   122449.3
# 1        Alaska    25744.8    24170.4   24732.6   26778.3    28420.4
# 2       Arizona     132418   143392.4  155344.5  164611.6   171474.2
# 3      Arkansas    59865.6    62442.5   66816.7     68770    70601.4
# 4    California  1070523.6  1147841.6   1247093   1366561  1384111.2
# 5      Colorado   136675.3   150381.7  164226.8  180605.5   187571.9
# 6   Connecticut   138648.8   145495.4  152338.1  165898.7   173127.2
# 7      Delaware    32967.7    36783.2   40363.6   43389.4    46448.3
# 8       Florida     401723   430064.2  458318.6  489488.1   516689.6
# 9       Georgia   242596.2   264894.9  288994.3  307611.6     318753
# 10       Hawaii    37654.9    37624.4   39250.4   41500.2    42894.3
# 11        Idaho      29439    30983.9   34138.2   37992.8    37384.1
# 12     Illinois   415770.7   436166.7  459322.1  487212.7   502260.3
# ...

# %%
stategdp = stategdp[stategdp["Description"]=='All industry total']
stategdp.head()
# Out:
#             GeoName         Description      1997      1998      1999  \
# 0    United States*  All industry total   8577552   9062817   9630663
# 95          Alabama  All industry total  104087.4  109404.3  115030.9
# 186          Alaska  All industry total   25744.8   24170.4   24732.6
# 277         Arizona  All industry total    132418  143392.4  155344.5
# 368        Arkansas  All industry total   59865.6   62442.5   66816.7
#
#          2000      2001      2002      2003      2004    ...         2008  \
# 0    10252347  10581822  10936418  11458246  12213730    ...     14712845
# 95   119242.4  122449.3  127792.3  133739.2  146524.7    ...     172686.8
# 186   26778.3   28420.4   29605.3   31799.7   34970.7    ...      54752.4
# 277  164611.6  171474.2  179413.3  192751.2  205420.8    ...     259366.7
# 368     68770   70601.4   73950.4   78218.8   84624.5    ...      98955.3
#
#          2009      2010      2011      2012      2013      2014      2015  \
# ...

# %%
stategdp.rename(columns={'GeoName': 'State'}, inplace=True)

# %%
stategdp
# Out:
#                      State         Description       1997       1998  \
# 0           United States*  All industry total    8577552    9062817
# 95                 Alabama  All industry total   104087.4   109404.3
# 186                 Alaska  All industry total    25744.8    24170.4
# 277                Arizona  All industry total     132418   143392.4
# 368               Arkansas  All industry total    59865.6    62442.5
# 459             California  All industry total  1070523.6  1147841.6
# 550               Colorado  All industry total   136675.3   150381.7
# 641            Connecticut  All industry total   138648.8   145495.4
# 732               Delaware  All industry total    32967.7    36783.2
# 823   District of Columbia  All industry total    52451.9    54879.8
# 914                Florida  All industry total     401723   430064.2
# 1005               Georgia  All industry total   242596.2   264894.9
# 1096                Hawaii  All industry total    37654.9    37624.4
# ...

# %%
stategdp = stategdp[1:52]

# %%
stategdp = stategdp[stategdp["State"]!='District of Columbia']
stategdp
# Out:
#                State         Description       1997       1998      1999  \
# 95           Alabama  All industry total   104087.4   109404.3  115030.9
# 186           Alaska  All industry total    25744.8    24170.4   24732.6
# 277          Arizona  All industry total     132418   143392.4  155344.5
# 368         Arkansas  All industry total    59865.6    62442.5   66816.7
# 459       California  All industry total  1070523.6  1147841.6   1247093
# 550         Colorado  All industry total   136675.3   150381.7  164226.8
# 641      Connecticut  All industry total   138648.8   145495.4  152338.1
# 732         Delaware  All industry total    32967.7    36783.2   40363.6
# 914          Florida  All industry total     401723   430064.2  458318.6
# 1005         Georgia  All industry total   242596.2   264894.9  288994.3
# 1096          Hawaii  All industry total    37654.9    37624.4   39250.4
# 1187           Idaho  All industry total      29439    30983.9   34138.2
# ...

# %%
stategdp = stategdp.reset_index(drop=True)

# %%
stategdp
# Out:
#              State         Description       1997       1998      1999  \
# 0          Alabama  All industry total   104087.4   109404.3  115030.9
# 1           Alaska  All industry total    25744.8    24170.4   24732.6
# 2          Arizona  All industry total     132418   143392.4  155344.5
# 3         Arkansas  All industry total    59865.6    62442.5   66816.7
# 4       California  All industry total  1070523.6  1147841.6   1247093
# 5         Colorado  All industry total   136675.3   150381.7  164226.8
# 6      Connecticut  All industry total   138648.8   145495.4  152338.1
# 7         Delaware  All industry total    32967.7    36783.2   40363.6
# 8          Florida  All industry total     401723   430064.2  458318.6
# 9          Georgia  All industry total   242596.2   264894.9  288994.3
# 10          Hawaii  All industry total    37654.9    37624.4   39250.4
# 11           Idaho  All industry total      29439    30983.9   34138.2
# ...

# %%
stategdp = stategdp.drop(columns=['Description'])

# %%
stategdp
# Out:
#              State       1997       1998      1999      2000       2001  \
# 0          Alabama   104087.4   109404.3  115030.9  119242.4   122449.3
# 1           Alaska    25744.8    24170.4   24732.6   26778.3    28420.4
# 2          Arizona     132418   143392.4  155344.5  164611.6   171474.2
# 3         Arkansas    59865.6    62442.5   66816.7     68770    70601.4
# 4       California  1070523.6  1147841.6   1247093   1366561  1384111.2
# 5         Colorado   136675.3   150381.7  164226.8  180605.5   187571.9
# 6      Connecticut   138648.8   145495.4  152338.1  165898.7   173127.2
# 7         Delaware    32967.7    36783.2   40363.6   43389.4    46448.3
# 8          Florida     401723   430064.2  458318.6  489488.1   516689.6
# 9          Georgia   242596.2   264894.9  288994.3  307611.6     318753
# 10          Hawaii    37654.9    37624.4   39250.4   41500.2    42894.3
# 11           Idaho      29439    30983.9   34138.2   37992.8    37384.1
# ...
