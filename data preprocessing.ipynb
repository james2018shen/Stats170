# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # GDP

# %%
gdp = pd.read_csv("data/SAGDP2N__ALL_AREAS_1997_2017.csv")
gdp = gdp.drop(columns=['GeoFIPS','Region','TableName','ComponentName','Unit','IndustryId','IndustryClassification'])
gdp = gdp[gdp["Description"]=='All industry total']
gdp.head()
# Out:
#             GeoName         Description      1997      1998      1999  \
# 0    United States*  All industry total   8577552   9062817   9630663
# 95          Alabama  All industry total  104087.4  109404.3  115030.9
# 186          Alaska  All industry total   25744.8   24170.4   24732.6
# 277         Arizona  All industry total    132418  143392.4  155344.5
# 368        Arkansas  All industry total   59865.6   62442.5   66816.7
#
#          2000      2001      2002      2003      2004    ...         2008  \
# 0    10252347  10581822  10936418  11458246  12213730    ...     14712845
# 95   119242.4  122449.3  127792.3  133739.2  146524.7    ...     172686.8
# 186   26778.3   28420.4   29605.3   31799.7   34970.7    ...      54752.4
# 277  164611.6  171474.2  179413.3  192751.2  205420.8    ...     259366.7
# 368     68770   70601.4   73950.4   78218.8   84624.5    ...      98955.3
#
#          2009      2010      2011      2012      2013      2014      2015  \
# ...

# %%
gdp.rename(columns={'GeoName': 'State'}, inplace=True)
gdp = gdp[0:52]
gdp = gdp[gdp["State"]!='District of Columbia']
gdp = gdp.reset_index(drop=True)
gdp = gdp.drop(columns=['Description'])

# %%
gdp = gdp.drop(0)

# %%
gdp.to_pickle("/Users/jiahaoshen/Desktop/Stats170/newdata/gdp.pkl")

# %%
gdp.sort_values(by=['State'])
# Out:
#              State       1997       1998      1999      2000       2001  \
# 1          Alabama   104087.4   109404.3  115030.9  119242.4   122449.3
# 2           Alaska    25744.8    24170.4   24732.6   26778.3    28420.4
# 3          Arizona     132418   143392.4  155344.5  164611.6   171474.2
# 4         Arkansas    59865.6    62442.5   66816.7     68770    70601.4
# 5       California  1070523.6  1147841.6   1247093   1366561  1384111.2
# 6         Colorado   136675.3   150381.7  164226.8  180605.5   187571.9
# 7      Connecticut   138648.8   145495.4  152338.1  165898.7   173127.2
# 8         Delaware    32967.7    36783.2   40363.6   43389.4    46448.3
# 9          Florida     401723   430064.2  458318.6  489488.1   516689.6
# 10         Georgia   242596.2   264894.9  288994.3  307611.6     318753
# 11          Hawaii    37654.9    37624.4   39250.4   41500.2    42894.3
# 12           Idaho      29439    30983.9   34138.2   37992.8    37384.1
# ...

# %%
gdp.describe()
# Out:
#          State     1997     1998      1999      2000      2001      2002  \
# count       50       50       50        50        50        50        50
# unique      50       50       50        50        50        50        50
# top     Alaska  58339.9  16073.1  110251.8  489488.1  187571.9  362271.1
# freq         1        1        1         1         1         1         1
#
#            2003   2004      2005    ...        2008      2009    2010  \
# count        50     50        50    ...          50        50      50
# unique       50     50        50    ...          50        50      50
# top     78218.8  22666  696741.1    ...     54787.5  124340.7  422902
# freq          1      1         1    ...           1         1       1
#
#            2011    2012   2013      2014      2015     2016      2017
# count        50      50     50        50        50       50        50
# unique       50      50     50        50        50       50        50
# ...

# %%
gdp = gdp.as_matrix(columns=['1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
gdp = gdp.astype('float64')
gdp.shape
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (50, 18)

# %%
np.save("/Users/jiahaoshen/Desktop/Stats170/newdata/gdp.npy",gdp)

# %% [markdown]
# # Population

# %%
income = pd.read_csv("data/SAINC5N_1998_2018_ALL_AREAS.csv")
income =  income[(income["Description"]=='Population (persons) 2/')]       
income = income.drop(columns=['GeoFIPS','Region','TableName','Unit','IndustryClassification','IndustryClassification','LineCode'])
income.rename(columns={'GeoName': 'State'}, inplace=True)
income = income.reset_index(drop=True)
income = income[(income["State"]!='New England')
       &(income["State"]!='Mideast')
       &(income["State"]!='Great Lakes')
       &(income["State"]!='Plains')
       &(income["State"]!='Southeast')
       &(income["State"]!='Southwest')
       &(income["State"]!='Rocky Mountain') 
       &(income["State"]!='Far West')
       &(income["State"]!='District of Columbia')]
income.replace(['Population (persons) 2/'],['Population'], inplace=True)
income = income.drop([0])
income
# Out:
#              State Description      1998      1999      2000      2001  \
# 1          Alabama  Population   4404701   4430141   4452173   4467634
# 2           Alaska  Population    619932    624779    627963    633714
# 3          Arizona  Population   4883342   5023823   5160586   5273477
# 4         Arkansas  Population   2626289   2651860   2678588   2691571
# 5       California  Population  32987675  33499204  33987977  34479458
# 6         Colorado  Population   4116639   4226018   4326921   4425687
# 7      Connecticut  Population   3365352   3386401   3411777   3432835
# 8         Delaware  Population    763335    774990    786373    795699
# 10         Florida  Population  15486559  15759421  16047515  16356966
# 11         Georgia  Population   7863536   8045965   8227303   8377038
# 12          Hawaii  Population   1215233   1210300   1213519   1225948
# 13           Idaho  Population   1252330   1275674   1299430   1319962
# ...

# %%
income=income.sort_values(by=['State'])
income = income.as_matrix(columns=['1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %%
income = income.astype('int64')

# %%
income.shape
# Out:
# (50, 18)

# %%
np.save("/Users/jiahaoshen/Desktop/Stats170/newdata/population.npy",income)

# %%
income = pd.read_csv("data/SAINC5N_1998_2018_ALL_AREAS.csv")
income.head()
income = income[(income["Description"]=='Per capita personal income (dollars) 3/')]
income = income.drop(columns=['GeoFIPS','Region','TableName','Unit','IndustryClassification','IndustryClassification','LineCode'])
income.rename(columns={'GeoName': 'State'}, inplace=True)
income = income.reset_index(drop=True)
income = income[(income["State"]!='New England')
       &(income["State"]!='Mideast')
       &(income["State"]!='Great Lakes')
       &(income["State"]!='Plains')
       &(income["State"]!='Southeast')
       &(income["State"]!='Southwest')
       &(income["State"]!='Rocky Mountain') 
       &(income["State"]!='Far West')
       &(income["State"]!='District of Columbia')]
income.replace(['Per capita personal income (dollars) 3/'],['Income/Person'], inplace=True)
income = income.drop([0])
income=income.sort_values(by=['State'])
income = income.as_matrix(columns=['1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
income = income.astype('int64')
income.shape
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# (50, 18)

# %%
np.save("/Users/jiahaoshen/Desktop/Stats170/newdata/incomeperson.npy",income)

# %%
income = pd.read_csv("data/SAINC5N_1998_2018_ALL_AREAS.csv")
income.head()
income = income[(income["Description"]=='Personal income (thousands of dollars)')]
income = income.drop(columns=['GeoFIPS','Region','TableName','Unit','IndustryClassification','IndustryClassification','LineCode'])
income.rename(columns={'GeoName': 'State'}, inplace=True)
income = income.reset_index(drop=True)
income = income[(income["State"]!='New England')
       &(income["State"]!='Mideast')
       &(income["State"]!='Great Lakes')
       &(income["State"]!='Plains')
       &(income["State"]!='Southeast')
       &(income["State"]!='Southwest')
       &(income["State"]!='Rocky Mountain') 
       &(income["State"]!='Far West')
       &(income["State"]!='District of Columbia')]
income.replace(['Personal income (thousands of dollars)'],['Income'], inplace=True)
income = income.drop([0])
income=income.sort_values(by=['State'])
income = income.as_matrix(columns=['1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
income = income.astype('int64')
income.shape
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# (50, 18)

# %%
np.save("/Users/jiahaoshen/Desktop/Stats170/newdata/income.npy",income)

# %% [markdown]
# # Suicide

# %%
mortality = pd.read_csv("data/NCHS_-_Leading_Causes_of_Death__United_States.csv", header=0)
mortality.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2016  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries     Alabama    2755                     55.5
# 1  Unintentional injuries      Alaska     439                     63.1
# 2  Unintentional injuries     Arizona    4010                     54.2
# 3  Unintentional injuries    Arkansas    1604                     51.8
# 4  Unintentional injuries  California   13213                     32.0

# %%
suicide = mortality[mortality['Cause Name'] == 'Suicide']
suicide = suicide[suicide['State']!= 'District of Columbia']
suicide.drop(columns=['113 Cause Name','Cause Name','Age-adjusted Death Rate'])
# Out:
#       Year      State  Deaths
# 8475  2016    Alabama     788
# 8476  2015    Alabama     750
# 8477  2014    Alabama     715
# 8478  2013    Alabama     721
# 8479  2012    Alabama     724
# 8480  2011    Alabama     654
# 8481  2010    Alabama     679
# 8482  2009    Alabama     673
# 8483  2008    Alabama     604
# 8484  2007    Alabama     592
# 8485  2006    Alabama     580
# 8486  2005    Alabama     535
# 8487  2004    Alabama     541
# 8488  2003    Alabama     521
# 8489  2002    Alabama     514
# 8490  2001    Alabama     512
# 8491  2000    Alabama     583
# 8492  1999    Alabama     555
# 8493  2016     Alaska     193
# 8494  2015     Alaska     201
# 8495  2014     Alaska     167
# 8496  2013     Alaska     171
# 8497  2012     Alaska     168
# 8498  2011     Alaska     143
# 8499  2010     Alaska     164
# 8500  2009     Alaska     143
# 8501  2008     Alaska     169
# 8502  2007     Alaska     149
# 8503  2006     Alaska     135
# 8504  2005     Alaska     131
# ...

# %%
suicide.pivot(index='Year', columns='State', values='Deaths')
# Out:
# State  Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1999       555      96      766       336        3077       574          274
# 2000       583     137      784       349        2969       613          304
# 2001       512     102      767       382        2831       722          283
# 2002       514     132      886       377        3228       727          260
# 2003       521     124      840       374        3397       728          272
# 2004       541     155      880       361        3368       797          294
# 2005       535     131      945       400        3206       800          295
# 2006       580     135      979       376        3334       730          292
# 2007       592     149     1016       402        3602       811          271
# 2008       604     169      972       447        3775       803          315
# 2009       673     143     1060       422        3823       941          316
# ...

# %%
suicide = suicide.pivot(index='State', columns='Year', values='Deaths')

# %%
suicide
# Out:
# Year             1999   2000   2001   2002   2003   2004   2005   2006   2007  \
# State
# Alabama           555    583    512    514    521    541    535    580    592
# Alaska             96    137    102    132    124    155    131    135    149
# Arizona           766    784    767    886    840    880    945    979   1016
# Arkansas          336    349    382    377    374    361    400    376    402
# California       3077   2969   2831   3228   3397   3368   3206   3334   3602
# Colorado          574    613    722    727    728    797    800    730    811
# Connecticut       274    304    283    260    272    294    295    292    271
# Delaware           86     82    108     74     94     93     83     91     95
# Florida          2029   2086   2314   2338   2297   2389   2347   2440   2587
# Georgia           873    847    935    909    972    973    924    923    997
# Hawaii            136    137    136    120    131    116    107    120    133
# ...

# %%
type(suicide)
# Out:
# pandas.core.frame.DataFrame

# %%
suicide.to_pickle("/Users/jiahaoshen/Desktop/Stats170/newdata/suicide.pkl")

# %%
suicide = suicide.drop(['United States'])
suicide.reset_index()
# Out:
# Year           State  1999  2000  2001  2002  2003  2004  2005  2006  2007  \
# 0            Alabama   555   583   512   514   521   541   535   580   592
# 1             Alaska    96   137   102   132   124   155   131   135   149
# 2            Arizona   766   784   767   886   840   880   945   979  1016
# 3           Arkansas   336   349   382   377   374   361   400   376   402
# 4         California  3077  2969  2831  3228  3397  3368  3206  3334  3602
# 5           Colorado   574   613   722   727   728   797   800   730   811
# 6        Connecticut   274   304   283   260   272   294   295   292   271
# 7           Delaware    86    82   108    74    94    93    83    91    95
# 8            Florida  2029  2086  2314  2338  2297  2389  2347  2440  2587
# 9            Georgia   873   847   935   909   972   973   924   923   997
# 10            Hawaii   136   137   136   120   131   116   107   120   133
# ...

# %%
suicide=suicide.sort_values(by=['State'])
suicide = suicide.as_matrix(columns=['1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
suicide = suicide.astype('int64')
suicide.shape
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# (50, 18)

# %%
np.save("/Users/jiahaoshen/Desktop/Stats170/newdata/suicide.npy",suicide)

# %% [markdown]
# # PCE

# %%
pce = pd.read_csv("data/SAEXP1_1997_2017_ALL_AREAS_.csv")
pce = pce[pce["Description"]=='Personal consumption expenditures']
pce = pce.drop(columns=['GeoFIPS','Region','TableName','ComponentName','Unit','Line','IndustryClassification'])
pce.head()
# Out:
#           GeoName                        Description       1997       1998  \
# 0   United States  Personal consumption expenditures  5534091.8  5874285.0
# 24        Alabama  Personal consumption expenditures    74340.3    77946.9
# 48         Alaska  Personal consumption expenditures    13799.3    14475.2
# 72        Arizona  Personal consumption expenditures    91972.3    99006.9
# 96       Arkansas  Personal consumption expenditures    41057.2    43456.6
#
#          1999       2000       2001       2002       2003       2004  \
# 0   6275655.2  6758605.7  7061876.3  7338427.6  7717658.4  8206825.4
# 24    82570.0    87080.2    90325.4    94859.3    99368.5   105420.7
# 48    15414.0    16578.0    17624.6    18929.7    20110.1    21414.2
# 72   107470.5   116521.5   121913.8   128044.8   135951.0   147499.2
# 96    46556.9    49704.0    51688.4    53668.9    56460.0    59980.2
#
#        ...           2008       2009        2010        2011        2012  \
# ...

# %%
pcep = pd.read_csv("data/SAEXP2_1997_2017_ALL_AREAS_.csv")
pcep = pcep[pcep["Description"]=='Per capita personal consumption expenditures']
pcep = pcep.drop(columns=['GeoFIPS','Region','TableName','ComponentName','Unit','Line','IndustryClassification'])
pcep.head()
# Out:
#           GeoName                                   Description     1997  \
# 0   United States  Per capita personal consumption expenditures  20298.0
# 24        Alabama  Per capita personal consumption expenditures  17020.0
# 48         Alaska  Per capita personal consumption expenditures  22512.0
# 72        Arizona  Per capita personal consumption expenditures  19416.0
# 96       Arkansas  Per capita personal consumption expenditures  15785.0
#
#        1998     1999     2000     2001     2002     2003     2004   ...     \
# 0   21295.0  22490.0  23953.0  24781.0  25514.0  26603.0  28028.0   ...
# 24  17696.0  18638.0  19559.0  20218.0  21174.0  22065.0  23268.0   ...
# 48  23350.0  24671.0  26400.0  27812.0  29470.0  31014.0  32481.0   ...
# 72  20274.0  21392.0  22579.0  23118.0  23728.0  24672.0  26095.0   ...
# 96  16547.0  17556.0  18556.0  19204.0  19834.0  20721.0  21813.0   ...
#
#        2008     2009     2010     2011     2012     2013     2014     2015  \
# ...

# %%
pce.rename(columns={'GeoName': 'State'}, inplace=True)
pcep.rename(columns={'GeoName': 'State'}, inplace=True)
pce = pce[pce["State"]!='District of Columbia']
pcep = pcep[pcep["State"]!='District of Columbia']
pce = pce.reset_index(drop=True)
pcep = pcep.reset_index(drop=True)

# %%
pce = pce[1:51]
pcep = pcep[1:51]

# %%
pce=pce.sort_values(by=['State'])
pce = pce.as_matrix(columns=['1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
pce = pce.astype('float64')
pce.shape
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# (50, 18)

# %%
pcep=pcep.sort_values(by=['State'])
pcep = pcep.as_matrix(columns=['1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
pcep = pcep.astype('float64')
pcep.shape
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# (50, 18)

# %%
np.save("/Users/jiahaoshen/Desktop/Stats170/newdata/pce.npy",pce)
np.save("/Users/jiahaoshen/Desktop/Stats170/newdata/pcep.npy",pcep)

# %% [markdown]
# # Unemployment

# %%
employ1 = pd.read_csv("data/CAEMP25S__ALL_STATES_1969_2000.csv", encoding = "Latin-1")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
employ2 = pd.read_csv("data/CAEMP25N__ALL_STATES_2001_2017.csv",encoding = "Latin-1")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
employ1 = employ1[employ1['Description']=='Total employment (number of jobs)']
employ1=employ1[['GeoName','Description','1999','2000']]
employ1 = employ1[~employ1.GeoName.str.contains(",")]
employ1 = employ1[1:52]
employ1 = employ1.drop(8096)

# %%
employ1.reset_index(drop=True, inplace=True)
employ1
# Out:
#            GeoName                        Description      1999      2000
# 0          Alabama  Total employment (number of jobs)   2378217   2392225
# 1           Alaska  Total employment (number of jobs)    381307    389734
# 2          Arizona  Total employment (number of jobs)   2695892   2801510
# 3         Arkansas  Total employment (number of jobs)   1460374   1482449
# 4       California  Total employment (number of jobs)  18852334  19228895
# 5         Colorado  Total employment (number of jobs)   2808435   2918002
# 6      Connecticut  Total employment (number of jobs)   2070018   2118177
# 7         Delaware  Total employment (number of jobs)    491018    503458
# 8          Florida  Total employment (number of jobs)   8577884   8881279
# 9          Georgia  Total employment (number of jobs)   4728750   4860810
# 10          Hawaii  Total employment (number of jobs)    738111    749439
# 11           Idaho  Total employment (number of jobs)    747188    776910
# ...

# %%
employ2 = employ2[employ2['Description']=='Total employment (number of jobs)']
employ2=employ2[['GeoName','Description','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011',
                '2012','2013','2014','2015','2016']]
employ2 = employ2[~employ2.GeoName.str.contains(",")]
employ2 = employ2[1:52]
employ2 = employ2.drop(11616)

# %%
employ2.reset_index(drop=True, inplace=True)
#employ2 = employ2.drop(['index'],axis=1)
employ2
# Out:
#            GeoName                        Description      2001      2002  \
# 0          Alabama  Total employment (number of jobs)   2376053   2364828
# 1           Alaska  Total employment (number of jobs)    394565    402187
# 2          Arizona  Total employment (number of jobs)   2829002   2847095
# 3         Arkansas  Total employment (number of jobs)   1482587   1478929
# 4       California  Total employment (number of jobs)  19341458  19358164
# 5         Colorado  Total employment (number of jobs)   2941583   2916941
# 6      Connecticut  Total employment (number of jobs)   2125253   2117734
# 7         Delaware  Total employment (number of jobs)    502735    500640
# 8          Florida  Total employment (number of jobs)   8938947   9055715
# 9          Georgia  Total employment (number of jobs)   4871814   4858288
# 10          Hawaii  Total employment (number of jobs)    752548    757721
# 11           Idaho  Total employment (number of jobs)    783399    791311
# ...

# %%
employ2 = employ2.drop(columns=['GeoName','Description'])

# %%
employ = pd.concat([employ1, employ2], axis=1)

# %%
employ
# Out:
#            GeoName                        Description      1999      2000  \
# 0          Alabama  Total employment (number of jobs)   2378217   2392225
# 1           Alaska  Total employment (number of jobs)    381307    389734
# 2          Arizona  Total employment (number of jobs)   2695892   2801510
# 3         Arkansas  Total employment (number of jobs)   1460374   1482449
# 4       California  Total employment (number of jobs)  18852334  19228895
# 5         Colorado  Total employment (number of jobs)   2808435   2918002
# 6      Connecticut  Total employment (number of jobs)   2070018   2118177
# 7         Delaware  Total employment (number of jobs)    491018    503458
# 8          Florida  Total employment (number of jobs)   8577884   8881279
# 9          Georgia  Total employment (number of jobs)   4728750   4860810
# 10          Hawaii  Total employment (number of jobs)    738111    749439
# 11           Idaho  Total employment (number of jobs)    747188    776910
# ...

# %%
employ=employ.sort_values(by=['GeoName'])
employ = employ.as_matrix(columns=['1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016'])
employ = employ.astype('int64')
employ.shape
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# (50, 18)

# %%
np.save("/Users/jiahaoshen/Desktop/Stats170/newdata/employ.npy",employ)
