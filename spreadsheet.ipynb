# %%
import pandas as pd
import numpy as np

# %%
sheet = pd.read_excel('/Users/jiahaoshen/Downloads/Section6All_xls.xlsx', sheet_name=None)

# %%
sheet
# Out:
# OrderedDict([('Contents',
#                   Unnamed: 0 Unnamed: 1                                         Unnamed: 2
#               0          NaN       Code                                              Title
#               1          NaN        NaN                                                NaN
#               2          NaN    T60100B  Table 6.1B. National Income Without Capital Co...
#               3          NaN    T60100C  Table 6.1C. National Income Without Capital Co...
#               4          NaN    T60100D  Table 6.1D. National Income Without Capital Co...
#               5          NaN    T60200A  Table 6.2A. Compensation of Employees by Industry
#               6          NaN    T60200B  Table 6.2B. Compensation of Employees by Industry
#               7          NaN    T60200C  Table 6.2C. Compensation of Employees by Industry
#               8          NaN    T60200D  Table 6.2D. Compensation of Employees by Industry
# ...

# %%
xlsx = pd.ExcelFile('/Users/jiahaoshen/Downloads/Section6All_xls.xlsx')
econ_sheets = []
for sheet in xlsx.sheet_names:
    econ_sheets.append(xlsx.parse(sheet))

# %%
econ_sheets[0]
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2
# 0          NaN       Code                                              Title
# 1          NaN        NaN                                                NaN
# 2          NaN    T60100B  Table 6.1B. National Income Without Capital Co...
# 3          NaN    T60100C  Table 6.1C. National Income Without Capital Co...
# 4          NaN    T60100D  Table 6.1D. National Income Without Capital Co...
# 5          NaN    T60200A  Table 6.2A. Compensation of Employees by Industry
# 6          NaN    T60200B  Table 6.2B. Compensation of Employees by Industry
# 7          NaN    T60200C  Table 6.2C. Compensation of Employees by Industry
# 8          NaN    T60200D  Table 6.2D. Compensation of Employees by Industry
# 9          NaN    T60300A         Table 6.3A. Wages and Salaries by Industry
# 10         NaN    T60300B         Table 6.3B. Wages and Salaries by Industry
# ...

# %%
econ_sheets[1]
# Out:
#    Table 6.1B. National Income Without Capital Consumption Adjustment by Industry  \
# 0                               [Millions of dollars]
# 1                       Annual data from 1948 to 1987
# 2                         Bureau of Economic Analysis
# 3                        Data published July 27, 2018
# 4                    File created Mar 27 2019  1:32PM
# 5                                                 NaN
# 6                                                Line
# 7                                                   1
# 8                                                   2
# 9                                                   3
# 10                                                  4
# 11                                                  5
# 12                                                  6
# 13                                                  7
# 14                                                  8
# 15                                                  9
# ...

# %%
for sheet in xlsx.sheet_names:
    print(sheet)
# Out:
# Contents
# T60100B-A
# T60100B-Q
# T60100C-A
# T60100C-Q
# T60100D-A
# T60100D-Q
# T60200A-A
# T60200B-A
# T60200C-A
# T60200D-A
# T60300A-A
# T60300B-A
# T60300C-A
# T60300D-A
# T60400A-A
# T60400B-A
# T60400C-A
# T60400D-A
# T60500A-A
# T60500B-A
# T60500C-A
# T60500D-A
# T60600A-A
# T60600B-A
# T60600C-A
# T60600D-A
# T60700A-A
# T60700B-A
# T60700C-A
# T60700D-A
# T60800A-A
# T60800B-A
# T60800C-A
# T60800D-A
# T60900B-A
# T60900C-A
# T60900D-A
# T61000B-A
# T61000C-A
# T61000D-A
# T61100A-A
# T61100B-A
# T61100C-A
# T61100D-A
# T61200A-A
# T61200B-A
# T61200C-A
# T61200D-A
# T61300A-A
# T61300B-A
# T61300C-A
# T61300D-A
# T61400A-A
# T61400B-A
# T61400C-A
# T61400D-A
# T61500A-A
# T61500B-A
# T61500C-A
# T61500D-A
# T61600A-A
# T61600B-A
# T61600B-Q
# T61600C-A
# T61600C-Q
# T61600D-A
# T61600D-Q
# T61700A-A
# T61700B-A
# T61700C-A
# T61700D-A
# T61800A-A
# T61800B-A
# T61800C-A
# T61800D-A
# T61900A-A
# T61900B-A
# T61900C-A
# T61900D-A
# T62000A-A
# T62000B-A
# T62000C-A
# ...
